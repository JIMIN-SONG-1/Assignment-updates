# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C://Users/302-24/Downloads/한국환경공단_도로 재비산먼지 측정 정보_20250228.csv", encoding="cp949")

# %%
print(df.head())
# Out:
#          측정일자   측정시간  지역  지역명    도로명                   시작점  \
# 0  2025-02-03  14:30  경기  파주시   책향기로     경기도 파주시 와동동 1421도
# 1  2025-02-03  14:16  경기  파주시   심학산로     경기도 파주시 와동동 1421도
# 2  2025-02-03  14:05  경기  파주시    미래로   경기도 파주시 당하동 650-1 도
# 3  2025-02-03  14:01  경기  파주시  와석순환로     경기도 파주시 와동동 1421도
# 4  2025-02-03  13:49  경기  파주시    경의로  경기도 파주시 아동동 299-16 도
#
#                        종점  기온  습도  재비산먼지 평균농도 오염범례
# 0      경기도 파주시 동패동 386-8전  -2  39          81   좋음
# 1     경기도 파주시 문발동 541-3 도  -3  40          90   좋음
# 2      경기도 파주시 동패동 22-3 도  -2  39         170   나쁨
# 3        경기도 파주시 야당동 998도  -2  39          94   좋음
# 4  경기도 고양시일산서구 덕이동 319-5도  -2  39          61   좋음

# %%
print(df.tail())
# Out:
#             측정일자   측정시간  지역  지역명   도로명                     시작점  \
# 1150  2025-02-28  10:03  인천  계양구  계양대로     인천광역시 계양구 계산동 1014도
# 1151  2025-02-28  09:53  인천  계양구  계산새로     인천광역시 계양구 계산동 1107도
# 1152  2025-02-28  09:43  인천  계양구   용종로      인천광역시 계양구 병방동 438도
# 1153  2025-02-28  09:34  인천  계양구  오조산로      인천광역시 계양구 작전동 941도
# 1154  2025-02-28  09:21  인천  계양구  봉오대로  인천광역시 계양구 효성동 산67-12 임
#
#                           종점  기온  습도  재비산먼지 평균농도  오염범례
# 1150    인천광역시 계양구 작전동 405-2도   9  43           3  매우좋음
# 1151     인천광역시 계양구 계산동 1035천   8  44           7  매우좋음
# 1152     인천광역시 계양구 계산동 1108도   7  45           6  매우좋음
# 1153      인천광역시 계양구 용종동 230도   8  45           5  매우좋음
# 1154  인천광역시 계양구 서운동 121-17 천   8  44           4  매우좋음

# %%
print(df.isnull().sum())
# Out:
# 측정일자          0
# 측정시간          0
# 지역            0
# 지역명           0
# 도로명           0
# 시작점           0
# 종점            0
# 기온            0
# 습도            0
# 재비산먼지 평균농도    0
# 오염범례          0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#             측정일자   측정시간  지역  지역명    도로명                     시작점  \
# 0     2025-02-03  14:30  경기  파주시   책향기로       경기도 파주시 와동동 1421도
# 1     2025-02-03  14:16  경기  파주시   심학산로       경기도 파주시 와동동 1421도
# 2     2025-02-03  14:05  경기  파주시    미래로     경기도 파주시 당하동 650-1 도
# 3     2025-02-03  14:01  경기  파주시  와석순환로       경기도 파주시 와동동 1421도
# 4     2025-02-03  13:49  경기  파주시    경의로    경기도 파주시 아동동 299-16 도
# ...          ...    ...  ..  ...    ...                     ...
# 1150  2025-02-28  10:03  인천  계양구   계양대로     인천광역시 계양구 계산동 1014도
# 1151  2025-02-28  09:53  인천  계양구   계산새로     인천광역시 계양구 계산동 1107도
# 1152  2025-02-28  09:43  인천  계양구    용종로      인천광역시 계양구 병방동 438도
# 1153  2025-02-28  09:34  인천  계양구   오조산로      인천광역시 계양구 작전동 941도
# 1154  2025-02-28  09:21  인천  계양구   봉오대로  인천광역시 계양구 효성동 산67-12 임
#
#                           종점  기온  습도  재비산먼지 평균농도  오염범례
# 0         경기도 파주시 동패동 386-8전  -2  39          81    좋음
# 1        경기도 파주시 문발동 541-3 도  -3  40          90    좋음
# ...

# %%
values = {'기온' : df['기온'].mean(), '습도' : df['습도'].mean()}
values
# Out:
# {'기온': 2.2675324675324675, '습도': 39.53506493506494}

# %%
df

# %%
import matplotlib.font_manager as fm
import os
import shutil

cache_dir = os.path.join(os.path.expanduser("~"), ".matplotlib")

if os.path.exists(cache_dir):
    shutil.rmtree(cache_dir)
    print("Matplotlib 폰트 캐시 삭제 완료")

fm._load_fontmanager()
print("Matplotlib 폰트 캐시 갱신 완료")

# %%
print(df.columns)
# Out:
# Index(['측정일자', '측정시간', '지역', '지역명', '도로명', '시작점', '종점', '기온', '습도',
#        '재비산먼지 평균농도', '오염범례', '시간대'],
#       dtype='object')

# %%
# 사용 가능한 폰트 확인
for font in fm.findSystemFonts():
    if "Nanum" in font or "Gothic" in font or "Malgun" in font:  # 한글 폰트 확인
        print(font)
# Out:
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumSquareEB.ttf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumBarunGothicBold.ttf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumSquareL.otf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumHumanBold.otf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumPen.ttf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumHumanEB.ttf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumSquareL.ttf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumHumanEL.ttf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumHumanRegular.otf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumMyeongjoEco.ttf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumSquareB.ttf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumGothicExtraBold.otf
# C:\Users\302-24\AppData\Local\Microsoft\Windows\Fonts\NanumSquareOTF.otf
# ...

# %%
import matplotlib.pyplot as plt

plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)

plt.figure()
plt.text(0.5, 0.5, "한글 폰트 테스트!", size=20, ha="center")
plt.show()

# %%
df = df.fillna(value = values)
df
# Out:
#             측정일자   측정시간  지역  지역명    도로명                     시작점  \
# 0     2025-02-03  14:30  경기  파주시   책향기로       경기도 파주시 와동동 1421도
# 1     2025-02-03  14:16  경기  파주시   심학산로       경기도 파주시 와동동 1421도
# 2     2025-02-03  14:05  경기  파주시    미래로     경기도 파주시 당하동 650-1 도
# 3     2025-02-03  14:01  경기  파주시  와석순환로       경기도 파주시 와동동 1421도
# 4     2025-02-03  13:49  경기  파주시    경의로    경기도 파주시 아동동 299-16 도
# ...          ...    ...  ..  ...    ...                     ...
# 1150  2025-02-28  10:03  인천  계양구   계양대로     인천광역시 계양구 계산동 1014도
# 1151  2025-02-28  09:53  인천  계양구   계산새로     인천광역시 계양구 계산동 1107도
# 1152  2025-02-28  09:43  인천  계양구    용종로      인천광역시 계양구 병방동 438도
# 1153  2025-02-28  09:34  인천  계양구   오조산로      인천광역시 계양구 작전동 941도
# 1154  2025-02-28  09:21  인천  계양구   봉오대로  인천광역시 계양구 효성동 산67-12 임
#
#                           종점  기온  습도  재비산먼지 평균농도  오염범례
# 0         경기도 파주시 동패동 386-8전  -2  39          81    좋음
# 1        경기도 파주시 문발동 541-3 도  -3  40          90    좋음
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = r"C://Users/302-24/AppData/Local/Microsoft/Windows/Fonts\NanumPen.ttf" 
font_prop = fm.FontProperties(fname=font_path)

plt.rcParams['font.family'] = font_prop.get_name()
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 부호 처리

plt.scatter(df[col_x], df[col_y], s=df[col_size] / 20)
plt.title("기온과 습도, 그리고 재비산먼지의 관계")
plt.xlabel(col_x)
plt.ylabel(col_y)
plt.show()
